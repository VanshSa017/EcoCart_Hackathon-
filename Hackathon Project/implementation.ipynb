# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Train Data

# %%
df_train=pd.read_csv('train.csv')
df_train.head()
# Out:
#            ID     Sex Bachelor Age Graduated            Career  \
# 0  1462220581    Male       No  41       Yes  Fashion Designer
# 1  1462220232  Female      Yes  38       Yes                HR
# 2  1462226544    Male      Yes  41       Yes  Fashion Designer
# 3  1462224171    Male       No  21        No            Doctor
# 4  1462226427  Female       No  37       Yes  Fashion Designer
#
#   Work Experience Family Expenses Family  Size Variable Segmentation  \
# 0               2             Low            3    Dog_6       Akshat
# 1               0         Average            2    Dog_6       Akshat
# 2               0            High            5    Dog_6      Bhavesh
# 3               0             Low            4    Dog_6        Darsh
# 4               0             Low            1    Dog_2      Bhavesh
#
#                                     Description
# 0     The specimen is reliable and experienced.
# 1     The specimen is reliable and experienced.
# 2     The specimen is reliable and experienced.
# 3  The specimen is responsible and hardworking.
# 4     The specimen is reliable and experienced.

# %% [markdown]
# Test Data

# %%
df_test=pd.read_csv('test.csv')
df_test.head()
# Out:
#            ID     Sex Bachelor   Age Graduated            Career  \
# 0  1462224759  Female      Yes  42.0        No         Scientist
# 1  1462220081  Female       No  41.0       Yes  Fashion Designer
# 2  1462226086  Female       No  18.0        No            Doctor
# 3  1462224440    Male       No  30.0       Yes            Doctor
# 4  1462222905    Male      Yes  81.0       Yes            Lawyer
#
#    Work Experience Family Expenses  Family  Size Variable  \
# 0              4.0             Low           1.0    Dog_6
# 1              0.0             Low           1.0    Dog_6
# 2              2.0             Low           5.0    Dog_6
# 3              1.0             Low           4.0    Dog_6
# 4              1.0             Low           1.0    Dog_6
#
#                                        Description
# 0        The specimen is reliable and experienced.
# 1        The specimen is reliable and experienced.
# 2  The specimen is rather joyful than responsible.
# 3        The specimen is reliable and experienced.
# 4        The specimen is reliable and experienced.

# %% [markdown]
# ## Feature Engineering

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               5647 non-null   int64
#  1   Sex              5615 non-null   object
#  2   Bachelor         5523 non-null   object
#  3   Age              5625 non-null   object
#  4   Graduated        5578 non-null   object
#  5   Career           5534 non-null   object
#  6   Work Experience  5074 non-null   object
#  7   Family Expenses  5616 non-null   object
#  8   Family  Size     5398 non-null   object
#  9   Variable         5595 non-null   object
#  10  Segmentation     5647 non-null   object
#  11  Description      5647 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 529.5+ KB

# %% [markdown]
# Standardize Column Name

# %%
df_train.columns=df_train.columns.str.strip()
df_test.columns=df_test.columns.str.strip()

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               5647 non-null   int64
#  1   Sex              5615 non-null   object
#  2   Bachelor         5523 non-null   object
#  3   Age              5625 non-null   object
#  4   Graduated        5578 non-null   object
#  5   Career           5534 non-null   object
#  6   Work Experience  5074 non-null   object
#  7   Family Expenses  5616 non-null   object
#  8   Family  Size     5398 non-null   object
#  9   Variable         5595 non-null   object
#  10  Segmentation     5647 non-null   object
#  11  Description      5647 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 529.5+ KB

# %% [markdown]
# Data Type Conversion

# %%
numConvert=['Age','Work Experience','Family  Size']

# Converting to Numeric 
for col in numConvert:
    df_train[col]=pd.to_numeric(df_train[col],errors='coerce') #If 'coerce', then invalid parsing will be set as NaN.
    df_test[col]=pd.to_numeric(df_test[col],errors='coerce')

# %%
df_train.dtypes
# Out:
# ID                   int64
# Sex                 object
# Bachelor            object
# Age                float64
# Graduated           object
# Career              object
# Work Experience    float64
# Family Expenses     object
# Family  Size       float64
# Variable            object
# Segmentation        object
# Description         object
# dtype: object

# %%
# Cleaning Family Expenses 
# NAN: None, Avege: Average, L0w:Low, 
temp={'NAN': None, 'Avege': 'Average', 'L0w': 'Low'}
df_train['Family Expenses']=df_train['Family Expenses'].replace(temp)
df_test['Family Expenses']=df_test['Family Expenses'].replace(temp)

# %%
# Clean 'Career' column
# Replace '1234', '_', 'Doktor' with NaN or corrected values
df_train['Career'] = df_train['Career'].replace({'1234': None, '_': None, 'Doktor': 'Doctor'})
df_test['Career'] = df_test['Career'].replace({'1234': None, '_': None, 'Doktor': 'Doctor'}) # Apply to test as well

# %%
df_train['Career'].unique()
# Out:
# array(['Fashion Designer', 'HR', 'Doctor', 'Lawyer', nan, 'Scientist',
#        'Singer', 'Content Creation', 'Housewife', None], dtype=object)

# %% [markdown]
# Handling Missing Values

# %%
df_train.isnull().count()
# Out:
# ID                 5647
# Sex                5647
# Bachelor           5647
# Age                5647
# Graduated          5647
# Career             5647
# Work Experience    5647
# Family Expenses    5647
# Family  Size       5647
# Variable           5647
# Segmentation       5647
# Description        5647
# dtype: int64

# %%
numeric_column=['Age','Work Experience','Family  Size']
cat_column=['Sex','Bachelor','Graduated','Career','Variable','Family Expenses']

for col in numeric_column:
    train_median=df_train[col].median()
    print(col,'=',train_median)
    df_train[col].fillna(train_median,inplace=True)
    df_test[col].fillna(train_median,inplace=True)

for col in cat_column:
    train_mode=df_train[col].mode()[0]
    print(col,'=',train_mode)
    df_train.fillna(train_mode,inplace=True)
    df_test.fillna(train_mode,inplace=True)
# Out:
# Age = 40.0
# Work Experience = 1.0
# Family  Size = 2.0
# Sex = Male
# Bachelor = Yes
# Graduated = Yes
# Career = Fashion Designer
# Variable = Dog_6
# Family Expenses = Low

# %% [markdown]
# Feature Encoding

# %%
## Oridnal maping
family_expenses_mapping = {'Low': 0, 'Average': 1, 'High': 2}
df_train['Family Expenses'] = df_train['Family Expenses'].map(family_expenses_mapping)
df_test['Family Expenses'] = df_test['Family Expenses'].map(family_expenses_mapping)

# %%
# 2. Drop 'ID' and 'Description' columns
df_train.drop(columns=['ID', 'Description'], inplace=True)
df_test.drop(columns=['ID', 'Description'], inplace=True)

# %%
## One Hot encoding
nominal_cols = ['Sex', 'Bachelor', 'Graduated', 'Career', 'Variable']

# Combine train and test for consistent one-hot encoding
# Temporarily drop 'Segmentation' from train_df for concatenation
combined_df = pd.concat([df_train.drop(columns=['Segmentation']), df_test], ignore_index=True)
combined_df = pd.get_dummies(combined_df, columns=nominal_cols, drop_first=True)

# Separate back into train and test
# Use .copy() to avoid SettingWithCopyWarning later
df_train_scaled = combined_df.iloc[:len(df_train)].copy()
df_test_scaled = combined_df.iloc[len(df_train):].copy()

# Add 'Segmentation' back to the training dataframe
df_train_scaled['Segmentation'] = df_train['Segmentation']


# Display info and head of processed dataframes
print("\nProcessed Train DataFrame Info after encoding and dropping columns:")
df_train_scaled.info()
print("\nProcessed Train DataFrame Head after encoding and dropping columns:")
print(df_train_scaled.head())

print("\nProcessed Test DataFrame Info after encoding and dropping columns:")
df_test_scaled.info()
print("\nProcessed Test DataFrame Head after encoding and dropping columns:")
print(df_test_scaled.head())
# Out:
# Processed Train DataFrame Info after encoding and dropping columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5647 non-null   float64
#  1   Work Experience          5647 non-null   float64
#  2   Family Expenses          5615 non-null   object
#  3   Family  Size             5647 non-null   float64
#  4   ID                       0 non-null      float64
#  5   Description              0 non-null      object
#  6   Sex_Male                 5647 non-null   bool
#  7   Bachelor_No              5647 non-null   bool
#  8   Bachelor_Yes             5647 non-null   bool
#  9   Graduated_No             5647 non-null   bool
#  10  Graduated_Yes            5647 non-null   bool
#  11  Career_Doctor            5647 non-null   bool
#  12  Career_Fashion Designer  5647 non-null   bool
#  13  Career_HR                5647 non-null   bool
#  14  Career_Housewife         5647 non-null   bool
#  15  Career_Lawyer            5647 non-null   bool
#  16  Career_Male              5647 non-null   bool
#  17  Career_Scientist         5647 non-null   bool
#  18  Career_Singer            5647 non-null   bool
#  19  Variable_Dog_2           5647 non-null   bool
#  20  Variable_Dog_3           5647 non-null   bool
#  21  Variable_Dog_4           5647 non-null   bool
#  22  Variable_Dog_5           5647 non-null   bool
#  23  Variable_Dog_6           5647 non-null   bool
#  24  Variable_Dog_7           5647 non-null   bool
#  25  Variable_Male            5647 non-null   bool
#  26  Segmentation             5647 non-null   object
# dtypes: bool(20), float64(4), object(3)
# memory usage: 419.2+ KB
#
# Processed Train DataFrame Head after encoding and dropping columns:
#     Age  Work Experience Family Expenses  Family  Size  ID Description  \
# 0  41.0              2.0             0.0           3.0 NaN         NaN
# 1  38.0              0.0             1.0           2.0 NaN         NaN
# 2  41.0              0.0             2.0           5.0 NaN         NaN
# 3  21.0              0.0             0.0           4.0 NaN         NaN
# 4  37.0              0.0             0.0           1.0 NaN         NaN
#
#    Sex_Male  Bachelor_No  Bachelor_Yes  Graduated_No  ...  Career_Scientist  \
# 0      True         True         False         False  ...             False
# 1     False        False          True         False  ...             False
# 2      True        False          True         False  ...             False
# 3      True         True         False          True  ...             False
# 4     False         True         False         False  ...             False
#
#    Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 0          False           False           False           False
# 1          False           False           False           False
# 2          False           False           False           False
# 3          False           False           False           False
# 4          False            True           False           False
#
#    Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male  Segmentation
# 0           False            True           False          False        Akshat
# 1           False            True           False          False        Akshat
# 2           False            True           False          False       Bhavesh
# 3           False            True           False          False         Darsh
# 4           False           False           False          False       Bhavesh
#
# [5 rows x 27 columns]
#
# Processed Test DataFrame Info after encoding and dropping columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2421 entries, 5647 to 8067
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      2407 non-null   float64
#  1   Work Experience          2154 non-null   float64
#  2   Family Expenses          2414 non-null   object
#  3   Family  Size             2318 non-null   float64
#  4   ID                       2421 non-null   float64
#  5   Description              2421 non-null   object
#  6   Sex_Male                 2421 non-null   bool
#  7   Bachelor_No              2421 non-null   bool
#  8   Bachelor_Yes             2421 non-null   bool
#  9   Graduated_No             2421 non-null   bool
#  10  Graduated_Yes            2421 non-null   bool
#  11  Career_Doctor            2421 non-null   bool
#  12  Career_Fashion Designer  2421 non-null   bool
#  13  Career_HR                2421 non-null   bool
#  14  Career_Housewife         2421 non-null   bool
#  15  Career_Lawyer            2421 non-null   bool
#  16  Career_Male              2421 non-null   bool
#  17  Career_Scientist         2421 non-null   bool
#  18  Career_Singer            2421 non-null   bool
#  19  Variable_Dog_2           2421 non-null   bool
#  20  Variable_Dog_3           2421 non-null   bool
#  21  Variable_Dog_4           2421 non-null   bool
#  22  Variable_Dog_5           2421 non-null   bool
#  23  Variable_Dog_6           2421 non-null   bool
#  24  Variable_Dog_7           2421 non-null   bool
#  25  Variable_Male            2421 non-null   bool
# dtypes: bool(20), float64(4), object(2)
# memory usage: 160.9+ KB
#
# Processed Test DataFrame Head after encoding and dropping columns:
#        Age  Work Experience Family Expenses  Family  Size            ID  \
# 5647  42.0              4.0             Low           1.0  1.462225e+09
# 5648  41.0              0.0             Low           1.0  1.462220e+09
# 5649  18.0              2.0             Low           5.0  1.462226e+09
# 5650  30.0              1.0             Low           4.0  1.462224e+09
# 5651  81.0              1.0             Low           1.0  1.462223e+09
#
#                                           Description  Sex_Male  Bachelor_No  \
# 5647        The specimen is reliable and experienced.     False        False
# 5648        The specimen is reliable and experienced.     False         True
# 5649  The specimen is rather joyful than responsible.     False         True
# 5650        The specimen is reliable and experienced.      True         True
# 5651        The specimen is reliable and experienced.      True        False
#
#       Bachelor_Yes  Graduated_No  ...  Career_Male  Career_Scientist  \
# 5647          True          True  ...        False              True
# 5648         False         False  ...        False             False
# 5649         False          True  ...        False             False
# 5650         False         False  ...        False             False
# 5651          True         False  ...        False             False
#
#       Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 5647          False           False           False           False
# 5648          False           False           False           False
# 5649          False           False           False           False
# 5650          False           False           False           False
# 5651          False           False           False           False
#
#       Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male
# 5647           False            True           False          False
# 5648           False            True           False          False
# 5649           False            True           False          False
# 5650           False            True           False          False
# 5651           False            True           False          False
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Identify numerical columns for scaling. These are the ones that were converted to numeric and imputed.
numerical_cols_for_scaling = ['Age', 'Work Experience', 'Family  Size']

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler ONLY on the training data's numerical columns and then transform them
df_train_scaled[numerical_cols_for_scaling] = scaler.fit_transform(df_train_scaled[numerical_cols_for_scaling])

# Transform the test data's numerical columns using the scaler fitted on the training data
df_test_scaled[numerical_cols_for_scaling] = scaler.transform(df_test_scaled[numerical_cols_for_scaling])

# Display info and head of processed dataframes after scaling
print("\nFinal Processed Train DataFrame Info:")
df_train_scaled.info()
print("\nFinal Processed Train DataFrame Head:")
print(df_train_scaled.head())

print("\nFinal Processed Test DataFrame Info:")
df_test_scaled.info()
print("\nFinal Processed Test DataFrame Head:")
print(df_test_scaled.head())

# Display value counts of the target variable 'Segmentation' (only in train_processed_df)
print("\nTarget Variable 'Segmentation' Value Counts (Train):")
print(df_train_scaled['Segmentation'].value_counts())
# Out:
# Final Processed Train DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5647 non-null   float64
#  1   Work Experience          5647 non-null   float64
#  2   Family Expenses          5615 non-null   object
#  3   Family  Size             5647 non-null   float64
#  4   ID                       0 non-null      float64
#  5   Description              0 non-null      object
#  6   Sex_Male                 5647 non-null   bool
#  7   Bachelor_No              5647 non-null   bool
#  8   Bachelor_Yes             5647 non-null   bool
#  9   Graduated_No             5647 non-null   bool
#  10  Graduated_Yes            5647 non-null   bool
#  11  Career_Doctor            5647 non-null   bool
#  12  Career_Fashion Designer  5647 non-null   bool
#  13  Career_HR                5647 non-null   bool
#  14  Career_Housewife         5647 non-null   bool
#  15  Career_Lawyer            5647 non-null   bool
#  16  Career_Male              5647 non-null   bool
#  17  Career_Scientist         5647 non-null   bool
#  18  Career_Singer            5647 non-null   bool
#  19  Variable_Dog_2           5647 non-null   bool
#  20  Variable_Dog_3           5647 non-null   bool
#  21  Variable_Dog_4           5647 non-null   bool
#  22  Variable_Dog_5           5647 non-null   bool
#  23  Variable_Dog_6           5647 non-null   bool
#  24  Variable_Dog_7           5647 non-null   bool
#  25  Variable_Male            5647 non-null   bool
#  26  Segmentation             5647 non-null   object
# dtypes: bool(20), float64(4), object(3)
# memory usage: 419.2+ KB
#
# Final Processed Train DataFrame Head:
#         Age  Work Experience Family Expenses  Family  Size  ID Description  \
# 0 -0.146347        -0.048361             0.0      0.046993 NaN         NaN
# 1 -0.325797        -0.196059             1.0     -0.281840 NaN         NaN
# 2 -0.146347        -0.196059             2.0      0.704658 NaN         NaN
# 3 -1.342676        -0.196059             0.0      0.375826 NaN         NaN
# 4 -0.385613        -0.196059             0.0     -0.610673 NaN         NaN
#
#    Sex_Male  Bachelor_No  Bachelor_Yes  Graduated_No  ...  Career_Scientist  \
# 0      True         True         False         False  ...             False
# 1     False        False          True         False  ...             False
# 2      True        False          True         False  ...             False
# 3      True         True         False          True  ...             False
# 4     False         True         False         False  ...             False
#
#    Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 0          False           False           False           False
# 1          False           False           False           False
# 2          False           False           False           False
# 3          False           False           False           False
# 4          False            True           False           False
#
#    Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male  Segmentation
# 0           False            True           False          False        Akshat
# 1           False            True           False          False        Akshat
# 2           False            True           False          False       Bhavesh
# 3           False            True           False          False         Darsh
# 4           False           False           False          False       Bhavesh
#
# [5 rows x 27 columns]
#
# Final Processed Test DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2421 entries, 5647 to 8067
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      2407 non-null   float64
#  1   Work Experience          2154 non-null   float64
#  2   Family Expenses          2414 non-null   object
#  3   Family  Size             2318 non-null   float64
#  4   ID                       2421 non-null   float64
#  5   Description              2421 non-null   object
#  6   Sex_Male                 2421 non-null   bool
#  7   Bachelor_No              2421 non-null   bool
#  8   Bachelor_Yes             2421 non-null   bool
#  9   Graduated_No             2421 non-null   bool
#  10  Graduated_Yes            2421 non-null   bool
#  11  Career_Doctor            2421 non-null   bool
#  12  Career_Fashion Designer  2421 non-null   bool
#  13  Career_HR                2421 non-null   bool
#  14  Career_Housewife         2421 non-null   bool
#  15  Career_Lawyer            2421 non-null   bool
#  16  Career_Male              2421 non-null   bool
#  17  Career_Scientist         2421 non-null   bool
#  18  Career_Singer            2421 non-null   bool
#  19  Variable_Dog_2           2421 non-null   bool
#  20  Variable_Dog_3           2421 non-null   bool
#  21  Variable_Dog_4           2421 non-null   bool
#  22  Variable_Dog_5           2421 non-null   bool
#  23  Variable_Dog_6           2421 non-null   bool
#  24  Variable_Dog_7           2421 non-null   bool
#  25  Variable_Male            2421 non-null   bool
# dtypes: bool(20), float64(4), object(2)
# memory usage: 160.9+ KB
#
# Final Processed Test DataFrame Head:
#            Age  Work Experience Family Expenses  Family  Size            ID  \
# 5647 -0.086531         0.099337             Low     -0.610673  1.462225e+09
# 5648 -0.146347        -0.196059             Low     -0.610673  1.462220e+09
# 5649 -1.522125        -0.048361             Low      0.704658  1.462226e+09
# 5650 -0.804328        -0.122210             Low      0.375826  1.462224e+09
# 5651  2.246310        -0.122210             Low     -0.610673  1.462223e+09
#
#                                           Description  Sex_Male  Bachelor_No  \
# 5647        The specimen is reliable and experienced.     False        False
# 5648        The specimen is reliable and experienced.     False         True
# 5649  The specimen is rather joyful than responsible.     False         True
# 5650        The specimen is reliable and experienced.      True         True
# 5651        The specimen is reliable and experienced.      True        False
#
#       Bachelor_Yes  Graduated_No  ...  Career_Male  Career_Scientist  \
# 5647          True          True  ...        False              True
# 5648         False         False  ...        False             False
# 5649         False          True  ...        False             False
# 5650         False         False  ...        False             False
# 5651          True         False  ...        False             False
#
#       Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 5647          False           False           False           False
# 5648          False           False           False           False
# 5649          False           False           False           False
# 5650          False           False           False           False
# 5651          False           False           False           False
#
#       Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male
# 5647           False            True           False          False
# 5648           False            True           False          False
# 5649           False            True           False          False
# 5650           False            True           False          False
# 5651           False            True           False          False
#
# [5 rows x 26 columns]
#
# Target Variable 'Segmentation' Value Counts (Train):
# Segmentation
# Darsh        1602
# Chaitanya    1377
# Akshat       1352
# Bhavesh      1316
# Name: count, dtype: int64

# %% [markdown]
# ## DataSet Splitting

# %%
from sklearn.model_selection import train_test_split
x=df_train_scaled.drop('Segmentation',axis=1)
y=df_train_scaled['Segmentation']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Final Dataset

# %%
df_train.head()
# Out:
#       Sex Bachelor   Age Graduated            Career  Work Experience  \
# 0    Male       No  41.0       Yes  Fashion Designer              2.0
# 1  Female      Yes  38.0       Yes                HR              0.0
# 2    Male      Yes  41.0       Yes  Fashion Designer              0.0
# 3    Male       No  21.0        No            Doctor              0.0
# 4  Female       No  37.0       Yes  Fashion Designer              0.0
#
#    Family Expenses  Family  Size Variable Segmentation
# 0              0.0           3.0    Dog_6       Akshat
# 1              1.0           2.0    Dog_6       Akshat
# 2              2.0           5.0    Dog_6      Bhavesh
# 3              0.0           4.0    Dog_6        Darsh
# 4              0.0           1.0    Dog_2      Bhavesh

# %%
df_test.head()
# Out:
#            ID     Sex Bachelor   Age Graduated            Career  \
# 0  1462224759  Female      Yes  42.0        No         Scientist
# 1  1462220081  Female       No  41.0       Yes  Fashion Designer
# 2  1462226086  Female       No  18.0        No            Doctor
# 3  1462224440    Male       No  30.0       Yes            Doctor
# 4  1462222905    Male      Yes  81.0       Yes            Lawyer
#
#    Work Experience Family Expenses  Family  Size Variable  \
# 0              4.0             Low           1.0    Dog_6
# 1              0.0             Low           1.0    Dog_6
# 2              2.0             Low           5.0    Dog_6
# 3              1.0             Low           4.0    Dog_6
# 4              1.0             Low           1.0    Dog_6
#
#                                        Description
# 0        The specimen is reliable and experienced.
# 1        The specimen is reliable and experienced.
# 2  The specimen is rather joyful than responsible.
# 3        The specimen is reliable and experienced.
# 4        The specimen is reliable and experienced.

# %%
df_train_scaled.head()
# Out:
#         Age  Work Experience Family Expenses  Family  Size  ID Description  \
# 0 -0.146347        -0.048361             0.0      0.046993 NaN         NaN
# 1 -0.325797        -0.196059             1.0     -0.281840 NaN         NaN
# 2 -0.146347        -0.196059             2.0      0.704658 NaN         NaN
# 3 -1.342676        -0.196059             0.0      0.375826 NaN         NaN
# 4 -0.385613        -0.196059             0.0     -0.610673 NaN         NaN
#
#    Sex_Male  Bachelor_No  Bachelor_Yes  Graduated_No  ...  Career_Scientist  \
# 0      True         True         False         False  ...             False
# 1     False        False          True         False  ...             False
# 2      True        False          True         False  ...             False
# 3      True         True         False          True  ...             False
# 4     False         True         False         False  ...             False
#
#    Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 0          False           False           False           False
# 1          False           False           False           False
# 2          False           False           False           False
# 3          False           False           False           False
# 4          False            True           False           False
#
#    Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male  Segmentation
# 0           False            True           False          False        Akshat
# 1           False            True           False          False        Akshat
# 2           False            True           False          False       Bhavesh
# 3           False            True           False          False         Darsh
# 4           False           False           False          False       Bhavesh
#
# [5 rows x 27 columns]

# %%
df_test_scaled.head()
# Out:
#            Age  Work Experience Family Expenses  Family  Size            ID  \
# 5647 -0.086531         0.099337             Low     -0.610673  1.462225e+09
# 5648 -0.146347        -0.196059             Low     -0.610673  1.462220e+09
# 5649 -1.522125        -0.048361             Low      0.704658  1.462226e+09
# 5650 -0.804328        -0.122210             Low      0.375826  1.462224e+09
# 5651  2.246310        -0.122210             Low     -0.610673  1.462223e+09
#
#                                           Description  Sex_Male  Bachelor_No  \
# 5647        The specimen is reliable and experienced.     False        False
# 5648        The specimen is reliable and experienced.     False         True
# 5649  The specimen is rather joyful than responsible.     False         True
# 5650        The specimen is reliable and experienced.      True         True
# 5651        The specimen is reliable and experienced.      True        False
#
#       Bachelor_Yes  Graduated_No  ...  Career_Male  Career_Scientist  \
# 5647          True          True  ...        False              True
# 5648         False         False  ...        False             False
# 5649         False          True  ...        False             False
# 5650         False         False  ...        False             False
# 5651          True         False  ...        False             False
#
#       Career_Singer  Variable_Dog_2  Variable_Dog_3  Variable_Dog_4  \
# 5647          False           False           False           False
# 5648          False           False           False           False
# 5649          False           False           False           False
# 5650          False           False           False           False
# 5651          False           False           False           False
#
#       Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  Variable_Male
# 5647           False            True           False          False
# 5648           False            True           False          False
# 5649           False            True           False          False
# 5650           False            True           False          False
# 5651           False            True           False          False
#
# [5 rows x 26 columns]

# %%
x_train.head()
# Out:
#            Age  Work Experience Family Expenses  Family  Size  ID Description  \
# 95   -0.206164        -0.196059             0.0     -0.610673 NaN         NaN
# 5571  0.451817        -0.122210             1.0      0.375826 NaN         NaN
# 842  -0.684695         0.468583             0.0      0.375826 NaN         NaN
# 1832 -1.043594        -0.122210             0.0     -0.610673 NaN         NaN
# 2409  0.870532        -0.196059             1.0      1.033491 NaN         NaN
#
#       Sex_Male  Bachelor_No  Bachelor_Yes  Graduated_No  ...  Career_Male  \
# 95       False        False          True         False  ...        False
# 5571     False        False          True         False  ...        False
# 842       True         True         False          True  ...        False
# 1832     False         True         False         False  ...        False
# 2409     False        False          True          True  ...        False
#
#       Career_Scientist  Career_Singer  Variable_Dog_2  Variable_Dog_3  \
# 95                True          False            True           False
# 5571              True          False           False           False
# 842              False           True           False           False
# 1832              True          False           False           False
# 2409              True          False           False           False
#
#       Variable_Dog_4  Variable_Dog_5  Variable_Dog_6  Variable_Dog_7  \
# 95             False           False           False           False
# 5571           False           False            True           False
# 842            False           False            True           False
# 1832           False           False            True           False
# 2409            True           False           False           False
#
#       Variable_Male
# 95            False
# 5571          False
# 842           False
# 1832          False
# 2409          False
#
# [5 rows x 26 columns]

# %%
y_train.head()
# Out:
# 95       Akshat
# 5571    Bhavesh
# 842      Akshat
# 1832      Darsh
# 2409     Akshat
# Name: Segmentation, dtype: object

# %%
y_train.head()
# Out:
# 95       Akshat
# 5571    Bhavesh
# 842      Akshat
# 1832      Darsh
# 2409     Akshat
# Name: Segmentation, dtype: object

# %%
y_test.head()
# Out:
# 4996    Chaitanya
# 4351       Akshat
# 3080        Darsh
# 2835        Darsh
# 1197        Darsh
# Name: Segmentation, dtype: object

# %%
df_train_scaled.to_csv('train_data_final_processed.csv', index=False)
print("Saved 'train_data_final_processed.csv' without the DataFrame index.")

# Save the processed test DataFrame without the index
df_test_scaled.to_csv('test_data_final_processed.csv', index=False)
print("Saved 'test_data_final_processed.csv' without the DataFrame index.")
# Out:
# Saved 'train_data_final_processed.csv' without the DataFrame index.
# Saved 'test_data_final_processed.csv' without the DataFrame index.
